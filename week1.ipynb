# %%
import pandas as pd

# %%
# step 1 (Reading csv file and printing it)
df=pd.read_csv("shorts.csv")
df
# Out:
#     product_id                  title  \
# 0     18947596              KASSUALLY
# 1     18946864             Cub McPaws
# 2     18921438          Gini and Jony
# 3     13624708                   Nike
# 4     18645102                 DChica
# 5     13695234  HRX by Hrithik Roshan
# 6     13610026  HRX by Hrithik Roshan
# 7     16051700         Miaz Lifestyle
# 8     14561272                  ASICS
# 9     16051704         Miaz Lifestyle
# 10    14494548             CUTECUMBER
# 11    14496210             CUTECUMBER
# 12    16043840                 BRINNS
# 13    18942852                 FITINC
# 14    18650484                CLUB A9
# 15    19024468            Blackberrys
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# ...

# %%
#step 2 (head/tail,shape,columns,datatypes)

df.shape
# Out:
# (21, 24)

# %%
df.head()
# Out:
#    product_id          title  \
# 0    18947596      KASSUALLY
# 1    18946864     Cub McPaws
# 2    18921438  Gini and Jony
# 3    13624708           Nike
# 4    18645102         DChica
#
#                                  product_description  rating  ratings_count  \
# 0    Women Green Slim Fit Denim Outdoor Denim Shorts     4.7              9
# 1                        Girls Yellow Printed Shorts     4.5             20
# 2                    Boys Black Denim Outdoor Shorts     4.6             28
# 3  Men Black Solid Standard Fit CHALLENGER DRI FI...     4.4            376
# 4    Girls Black Skinny Fit High-Rise Cycling Shorts     4.3             16
#
#    initial_price  discount  final_price currency  \
# 0         1799.0      67.0    "₹593.00"      INR
# 1         1499.0      53.0    "₹699.00"      INR
# 2         1599.0      25.0    "₹959.00"      INR
# 3         1795.0       NaN  "₹1,795.00"      INR
# 4          599.0      53.0    "₹599.00"      INR
#
# ...

# %%
df.head(7)
# Out:
#    product_id                  title  \
# 0    18947596              KASSUALLY
# 1    18946864             Cub McPaws
# 2    18921438          Gini and Jony
# 3    13624708                   Nike
# 4    18645102                 DChica
# 5    13695234  HRX by Hrithik Roshan
# 6    13610026  HRX by Hrithik Roshan
#
#                                  product_description  rating  ratings_count  \
# 0    Women Green Slim Fit Denim Outdoor Denim Shorts     4.7              9
# 1                        Girls Yellow Printed Shorts     4.5             20
# 2                    Boys Black Denim Outdoor Shorts     4.6             28
# 3  Men Black Solid Standard Fit CHALLENGER DRI FI...     4.4            376
# 4    Girls Black Skinny Fit High-Rise Cycling Shorts     4.3             16
# 5  HRX By Hrithik Roshan Women Medieval Blue,Wild...     4.4            150
# 6  HRX By Hrithik Roshan Men Black Forest & Golde...     4.2             84
#
#    initial_price  discount  final_price currency  \
# ...

# %%
df.tail()
# Out:
#     product_id                  title  \
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# 16  Women Mustard Yellow Play Up 3.0 Colourblocked...     3.6             10
# 17         Women Red & Navy Blue Printed Chino Shorts     4.7              9
# 18                                  Boys Green Shorts     4.5             61
# 19  Women White Printed Slim Fit High-Rise Denim O...     4.7             38
# 20                  Men Brown Printed Slim Fit Shorts     4.6             13
#
#     initial_price  discount  final_price currency  \
# 16         2499.0      25.0  "₹1,874.00"      INR
# 17         2999.0      40.0  "₹1,499.00"      INR
# 18         1399.0      30.0    "₹979.00"      INR
# 19         1899.0      66.0    "₹645.00"      INR
# ...

# %%
df.tail(6)
# Out:
#     product_id                  title  \
# 15    19024468            Blackberrys
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# 15            Men Pure Cotton Printed Slim Fit Shorts     4.1              9
# 16  Women Mustard Yellow Play Up 3.0 Colourblocked...     3.6             10
# 17         Women Red & Navy Blue Printed Chino Shorts     4.7              9
# 18                                  Boys Green Shorts     4.5             61
# 19  Women White Printed Slim Fit High-Rise Denim O...     4.7             38
# 20                  Men Brown Printed Slim Fit Shorts     4.6             13
#
#     initial_price  discount  final_price currency  \
# 15         1695.0      40.0  "₹1,017.00"      INR
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df["title"]))
print(type(df["rating"]))
print(type(df["seller_name"]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
#step3 Identify nullvalues and deal with it

df.isnull().sum()

# %%
df.fillna(df["initial_price"].mean(),inplace=True)
df
# Out:
#     product_id                  title  \
# 0     18947596              KASSUALLY
# 1     18946864             Cub McPaws
# 2     18921438          Gini and Jony
# 3     13624708                   Nike
# 4     18645102                 DChica
# 5     13695234  HRX by Hrithik Roshan
# 6     13610026  HRX by Hrithik Roshan
# 7     16051700         Miaz Lifestyle
# 8     14561272                  ASICS
# 9     16051704         Miaz Lifestyle
# 10    14494548             CUTECUMBER
# 11    14496210             CUTECUMBER
# 12    16043840                 BRINNS
# 13    18942852                 FITINC
# 14    18650484                CLUB A9
# 15    19024468            Blackberrys
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# ...

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
#step 4 Filter rows 

filter_rows=df[df["initial_price"]>1000]
print(filter_rows)
# Out:
#     product_id                  title  \
# 0     18947596              KASSUALLY
# 1     18946864             Cub McPaws
# 2     18921438          Gini and Jony
# 3     13624708                   Nike
# 5     13695234  HRX by Hrithik Roshan
# 6     13610026  HRX by Hrithik Roshan
# 7     16051700         Miaz Lifestyle
# 8     14561272                  ASICS
# 9     16051704         Miaz Lifestyle
# 12    16043840                 BRINNS
# 15    19024468            Blackberrys
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# 0     Women Green Slim Fit Denim Outdoor Denim Shorts     4.7              9
# 1                         Girls Yellow Printed Shorts     4.5             20
# ...

# %%
#selecting columns

df[["title","product_description"]]
# Out:
#                     title                                product_description
# 0               KASSUALLY    Women Green Slim Fit Denim Outdoor Denim Shorts
# 1              Cub McPaws                        Girls Yellow Printed Shorts
# 2           Gini and Jony                    Boys Black Denim Outdoor Shorts
# 3                    Nike  Men Black Solid Standard Fit CHALLENGER DRI FI...
# 4                  DChica    Girls Black Skinny Fit High-Rise Cycling Shorts
# 5   HRX by Hrithik Roshan  HRX By Hrithik Roshan Women Medieval Blue,Wild...
# 6   HRX by Hrithik Roshan  HRX By Hrithik Roshan Men Black Forest & Golde...
# 7          Miaz Lifestyle                  Women White Set Of 2 Biker Shorts
# 8                   ASICS  Court M 7In   Men Black Solid Mid-Rise Tennis ...
# 9          Miaz Lifestyle        Women Pack Of 2 Beige & White Sports Shorts
# 10             CUTECUMBER    Girls Pack Of 2 Printed Mid-Rise Regular Shorts
# ...

# %%
df[["rating","initial_price","title"]]
# Out:
#     rating  initial_price                  title
# 0      4.7         1799.0              KASSUALLY
# 1      4.5         1499.0             Cub McPaws
# 2      4.6         1599.0          Gini and Jony
# 3      4.4         1795.0                   Nike
# 4      4.3          599.0                 DChica
# 5      4.4         1499.0  HRX by Hrithik Roshan
# 6      4.2         1899.0  HRX by Hrithik Roshan
# 7      0.0         1999.0         Miaz Lifestyle
# 8      5.0         2299.0                  ASICS
# 9      0.0         1999.0         Miaz Lifestyle
# 10     4.3          650.0             CUTECUMBER
# 11     4.6          650.0             CUTECUMBER
# 12     0.0         1699.0                 BRINNS
# 13     4.4          999.0                 FITINC
# 14     4.5          699.0                CLUB A9
# 15     4.1         1695.0            Blackberrys
# 16     3.6         2499.0           UNDER ARMOUR
# 17     4.7         2999.0         Tommy Hilfiger
# ...

# %%
df["total_amount"]=df["initial_price"]*df["rating"]

# %%
df
# Out:
#     product_id                  title  \
# 0     18947596              KASSUALLY
# 1     18946864             Cub McPaws
# 2     18921438          Gini and Jony
# 3     13624708                   Nike
# 4     18645102                 DChica
# 5     13695234  HRX by Hrithik Roshan
# 6     13610026  HRX by Hrithik Roshan
# 7     16051700         Miaz Lifestyle
# 8     14561272                  ASICS
# 9     16051704         Miaz Lifestyle
# 10    14494548             CUTECUMBER
# 11    14496210             CUTECUMBER
# 12    16043840                 BRINNS
# 13    18942852                 FITINC
# 14    18650484                CLUB A9
# 15    19024468            Blackberrys
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# ...

# %%
#step 5 remove duplicates 

df=df.drop_duplicates()
print("Duplicates removed")
# Out:
# Duplicates removed

# %%
#step 6 Creating new column from existting ones 

df["total_amount"] = df["initial_price"] * df["rating"]

df
# Out:
#     product_id                  title  \
# 0     18947596              KASSUALLY
# 1     18946864             Cub McPaws
# 2     18921438          Gini and Jony
# 3     13624708                   Nike
# 4     18645102                 DChica
# 5     13695234  HRX by Hrithik Roshan
# 6     13610026  HRX by Hrithik Roshan
# 7     16051700         Miaz Lifestyle
# 8     14561272                  ASICS
# 9     16051704         Miaz Lifestyle
# 10    14494548             CUTECUMBER
# 11    14496210             CUTECUMBER
# 12    16043840                 BRINNS
# 13    18942852                 FITINC
# 14    18650484                CLUB A9
# 15    19024468            Blackberrys
# 16    17333612           UNDER ARMOUR
# 17    17332648         Tommy Hilfiger
# 18    15177608  HRX by Hrithik Roshan
# 19    18947600              KASSUALLY
# 20    18658050            Allen Solly
#
#                                   product_description  rating  ratings_count  \
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'total_amount'],
#       dtype='object')

# %%
df.to_csv("updated.csv",index=False)
